# %% [markdown]
# # WeatherPy
#
# ---
#
# **Brief Description**: This notebook reflects the analysis of weather patterns across more than 500 cities worldwide with varying distances from the equator. The entire report is organized and presented using scatter plots by ingesting data from a public API. A short written report that summarizes the key findings for each scatter plot is also presented in this notebook.
# ***
# > - **Requirement 1:** Relationship between weather variables and latitude: <br>
#        1. Latitude vs. Temperature <br>
#        2. Latitude vs. Humidity <br>
#        3. Latitude vs. Cloudiness <br>
#        4. Latitude vs. Wind Speed <br>
#
# > - **Requirement 2:** Linear Regression for each relationship: <br>
#        1. The plots are separated across each of Northern and Southern hemispheres to compute the linear regression.<br>
#        2. A function is used for the above which is subsequently called for each relationship with relevant parameters.<br>
# ***

# %%
# Dependencies and Setup
import matplotlib.pyplot as pyplt
import pandas as pd
import numpy as np
import requests
import time
import sys
import scipy.stats as st
from datetime import datetime
from scipy.stats import linregress

# Set the default size of the figure to display the scatter plots used later in the analysis
pyplt.rcParams["figure.figsize"] = [10, 6]

# Minor data wrangling to support display of the current date for plots
todays_date = datetime.date(datetime.now())

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Add the path for Citipy to the Python Path
sys.path.append('C:\\Users\\Nithya Ravi\\anaconda3\\envs\\dev\\Lib\\site-packages')

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ## Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
city_units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Initialize respective lists for each of parsed data elements in the JSON response
city_name = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

# Print to logger
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={city_units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country and date
        city_name.append(city_weather['name'])
        city_lat.append(city_weather['coord']['lat'])
        city_lng.append(city_weather['coord']['lon'])
        city_max_temp.append(city_weather['main']['temp_max'])
        city_humidity.append(city_weather['main']['humidity'])
        city_clouds.append(city_weather['clouds']['all'])
        city_wind.append(city_weather['wind']['speed'])
        city_country.append(city_weather['sys']['country'])
        city_date.append(city_weather['dt'])
        
    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | neyshabur
# Processing Record 2 of Set 1 | i-n-salah
# Processing Record 3 of Set 1 | flying fish cove
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | lihue
# Processing Record 7 of Set 1 | xining
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | haiku-pauwela
# Processing Record 11 of Set 1 | enewetak
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | savaneta
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | smithers
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | fort-shevchenko
# Processing Record 19 of Set 1 | mili
# Processing Record 20 of Set 1 | blackmans bay
# Processing Record 21 of Set 1 | poyang
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | ceeldheer
# Processing Record 24 of Set 1 | badger
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | antofagasta
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | utrik
# Processing Record 29 of Set 1 | porto novo
# Processing Record 30 of Set 1 | manicore
# Processing Record 31 of Set 1 | baki
# Processing Record 32 of Set 1 | qeshm
# Processing Record 33 of Set 1 | saudarkrokur
# Processing Record 34 of Set 1 | wailua homesteads
# Processing Record 35 of Set 1 | turkler
# City not found. Skipping...
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 
# Processing Record 0 of Set 5 | bowen
# Processing Record 1 of Set 5 | keflavik
# Processing Record 2 of Set 5 | sinabang
# Processing Record 3 of Set 5 | shubarshi
# Processing Record 4 of Set 5 | mutuali
# Processing Record 5 of Set 5 | northam
# Processing Record 6 of Set 5 | la paz
# Processing Record 7 of Set 5 | taro
# Processing Record 8 of Set 5 | prado
# Processing Record 9 of Set 5 | torrington
# Processing Record 10 of Set 5 | nadi
# Processing Record 11 of Set 5 | narimanov
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | assab
# Processing Record 14 of Set 5 | mcalester
# Processing Record 15 of Set 5 | jamestown
# Processing Record 16 of Set 5 | fale old settlement
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | mwinilunga
# Processing Record 19 of Set 5 | gumushkhane
# Processing Record 20 of Set 5 | wuchuan
# Processing Record 21 of Set 5 | paracuru
# Processing Record 22 of Set 5 | kone
# Processing Record 23 of Set 5 | antalaha
# Processing Record 24 of Set 5 | molo
# Processing Record 25 of Set 5 | port isabel
# Processing Record 26 of Set 5 | n'zeto
# Processing Record 27 of Set 5 | new glasgow
# Processing Record 28 of Set 5 | ovruch
# Processing Record 29 of Set 5 | bei'an
# Processing Record 30 of Set 5 | atafu village
# Processing Record 31 of Set 5 | pokaran
# Processing Record 32 of Set 5 | nabire
# Processing Record 33 of Set 5 | vicuna mackenna
# Processing Record 34 of Set 5 | kapa'a
# Processing Record 35 of Set 5 | labrador city
# Processing Record 36 of Set 5 | tamanrasset
# Processing Record 37 of Set 5 | nar'yan-mar
# Processing Record 38 of Set 5 | callao
# Processing Record 39 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 5 | el calafate
# Processing Record 41 of Set 5 | shanhecun
# Processing Record 42 of Set 5 | bocas del toro
# Processing Record 43 of Set 5 | xichang
# Processing Record 44 of Set 5 | colares
# Processing Record 45 of Set 5 | nikolayevsk-on-amure
# Processing Record 46 of Set 5 | constitucion
# Processing Record 47 of Set 5 | bikenibeu village
# Processing Record 48 of Set 5 | kavieng
# Processing Record 49 of Set 5 | nemuro
# Processing Record 0 of Set 6 | beira
# Processing Record 1 of Set 6 | qamdo
# Processing Record 2 of Set 6 | oriximina
# Processing Record 3 of Set 6 | sopot
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | vilyuysk
# Processing Record 6 of Set 6 | exu
# Processing Record 7 of Set 6 | bel ombre
# Processing Record 8 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 9 of Set 6 | leiyang
# Processing Record 10 of Set 6 | kolonia town
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | along
# Processing Record 13 of Set 6 | san matias
# Processing Record 14 of Set 6 | napili-honokowai
# Processing Record 15 of Set 6 | paragominas
# Processing Record 16 of Set 6 | nova sintra
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | suai
# City not found. Skipping...
# Processing Record 19 of Set 6 | damongo
# City not found. Skipping...
# Processing Record 20 of Set 6 | ambodifotatra
# Processing Record 21 of Set 6 | kitimat
# Processing Record 22 of Set 6 | oamaru
# Processing Record 23 of Set 6 | aioun
# Processing Record 24 of Set 6 | caleta de carquin
# Processing Record 25 of Set 6 | pisco
# Processing Record 26 of Set 6 | kitami
# Processing Record 27 of Set 6 | markaz-e hukumat-e darweshan
# Processing Record 28 of Set 6 | constantia
# Processing Record 29 of Set 6 | linqiong
# Processing Record 30 of Set 6 | hotan
# Processing Record 31 of Set 6 | seymour
# Processing Record 32 of Set 6 | vohipaho
# City not found. Skipping...
# Processing Record 33 of Set 6 | ammi moussa
# Processing Record 34 of Set 6 | manokwari
# Processing Record 35 of Set 6 | bayanhongor
# Processing Record 36 of Set 6 | vilyuchinsk
# Processing Record 37 of Set 6 | gaspe
# Processing Record 38 of Set 6 | aoulef
# Processing Record 39 of Set 6 | mbandaka
# Processing Record 40 of Set 6 | baukau
# Processing Record 41 of Set 6 | isle of arran
# City not found. Skipping...
# Processing Record 42 of Set 6 | baiyin
# Processing Record 43 of Set 6 | strathmore
# Processing Record 44 of Set 6 | freetown
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | dubois
# Processing Record 47 of Set 6 | kavaratti
# Processing Record 48 of Set 6 | basti
# Processing Record 49 of Set 6 | fortuna
# Processing Record 0 of Set 7 | fuglafjordur
# Processing Record 1 of Set 7 | sucua
# Processing Record 2 of Set 7 | amboasary
# Processing Record 3 of Set 7 | dwarka
# Processing Record 4 of Set 7 | tralee
# Processing Record 5 of Set 7 | malvan
# Processing Record 6 of Set 7 | nyuzen
# Processing Record 7 of Set 7 | yuzhno-kurilsk
# Processing Record 8 of Set 7 | noosa heads
# Processing Record 9 of Set 7 | kut chap
# Processing Record 10 of Set 7 | ishim
# Processing Record 11 of Set 7 | nadym
# Processing Record 12 of Set 7 | alaghsas
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | mogocha
# Processing Record 15 of Set 7 | mahajanga
# Processing Record 16 of Set 7 | vereshchagino
# Processing Record 17 of Set 7 | vorgashor
# Processing Record 18 of Set 7 | port saint john's
# Processing Record 19 of Set 7 | khandyga
# Processing Record 20 of Set 7 | talavera de la reina
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | plast
# Processing Record 23 of Set 7 | tobelo
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | kiskoros
# Processing Record 26 of Set 7 | al kharijah
# Processing Record 27 of Set 7 | dhidhdhoo
# Processing Record 28 of Set 7 | st. john's
# Processing Record 29 of Set 7 | qulsary
# Processing Record 30 of Set 7 | carahue
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | ranipur
# Processing Record 33 of Set 7 | umba
# Processing Record 34 of Set 7 | inhambane
# Processing Record 35 of Set 7 | sandnessjoen
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | krasnyy chikoy
# Processing Record 40 of Set 7 | floro
of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 16 of Set 9 | payallar
# Processing Record 17 of Set 9 | kayangel
# Processing Record 18 of Set 9 | faya-largeau
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | east london
# Processing Record 21 of Set 9 | la passe
# Processing Record 22 of Set 9 | new norfolk
# Processing Record 23 of Set 9 | griffith
# Processing Record 24 of Set 9 | plastun
# Processing Record 25 of Set 9 | guaratuba
# Processing Record 26 of Set 9 | port moresby
# Processing Record 27 of Set 9 | arraial do cabo
# Processing Record 28 of Set 9 | cabo san lucas
# Processing Record 29 of Set 9 | beyneu
# Processing Record 30 of Set 9 | madang
# Processing Record 31 of Set 9 | al muwayh
# Processing Record 32 of Set 9 | recreo
# Processing Record 33 of Set 9 | cole harbour
# Processing Record 34 of Set 9 | samfya
# Processing Record 35 of Set 9 | san felipe
# Processing Record 36 of Set 9 | jilib
# Processing Record 37 of Set 9 | suwayr
# Processing Record 38 of Set 9 | tsengel
# Processing Record 39 of Set 9 | pimentel
# Processing Record 40 of Set 9 | waounde
# Processing Record 41 of Set 9 | tarauaca
# Processing Record 42 of Set 9 | nelson bay
# Processing Record 43 of Set 9 | sao jose da coroa grande
# Processing Record 44 of Set 9 | tazacorte
# Processing Record 45 of Set 9 | wanning
# Processing Record 46 of Set 9 | socorro
# Processing Record 47 of Set 9 | fort st. john
# Processing Record 48 of Set 9 | kerikeri
# Processing Record 49 of Set 9 | grahamstown
# Processing Record 0 of Set 10 | mlyniv
# Processing Record 1 of Set 10 | nikel
# Processing Record 2 of Set 10 | moree
# Processing Record 3 of Set 10 | onguday
# Processing Record 4 of Set 10 | sake
# Processing Record 5 of Set 10 | pipar
# Processing Record 6 of Set 10 | basco
# Processing Record 7 of Set 10 | castillos
# Processing Record 8 of Set 10 | ketchikan
# Processing Record 9 of Set 10 | montpelier
# Processing Record 10 of Set 10 | la gi
# Processing Record 11 of Set 10 | goias
# Processing Record 12 of Set 10 | san jose del cabo
# Processing Record 13 of Set 10 | matheran
# Processing Record 14 of Set 10 | crane
# Processing Record 15 of Set 10 | urangan
# Processing Record 16 of Set 10 | vila real
# Processing Record 17 of Set 10 | timbuktu
# Processing Record 18 of Set 10 | mirny
# Processing Record 19 of Set 10 | peterhead
# Processing Record 20 of Set 10 | kodiak
# Processing Record 21 of Set 10 | bonthe
# Processing Record 22 of Set 10 | araguaina
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | morehead city
# Processing Record 25 of Set 10 | brainerd
# Processing Record 26 of Set 10 | razam
# Processing Record 27 of Set 10 | el nido
# Processing Record 28 of Set 10 | tommot
# Processing Record 29 of Set 10 | deschutes river woods
# Processing Record 30 of Set 10 | korsakov
# Processing Record 31 of Set 10 | las palmas de gran canaria
# Processing Record 32 of Set 10 | holualoa
# Processing Record 33 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 10 | yanbu
# Processing Record 35 of Set 10 | yeed
# Processing Record 36 of Set 10 | broome
# Processing Record 37 of Set 10 | laboulaye
# Processing Record 38 of Set 10 | kiunga
# Processing Record 39 of Set 10 | sungai penuh
# Processing Record 40 of Set 10 | laascaanood
# Processing Record 41 of Set 10 | amga
# Processing Record 42 of Set 10 | balqash
# Processing Record 43 of Set 10 | forster
# Processing Record 44 of Set 10 | at taj
# Processing Record 45 of Set 10 | bafoulabe
# Processing Record 46 of Set 10 | gisborne
# Processing Record 47 of Set 10 | mossel bay
# Processing Record 48 of Set 10 | tanjung selor
# City not found. Skipping...
# Processing Record 49 of Set 10 | an nuhud
# Processing Record 0 of Set 11 | san ignacio
# Processing Record 1 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 11 | sahavato
# City not found. Skipping...
# Processing Record 3 of Set 11 | turkmenbasy
# Processing Record 4 of Set 11 | rio gallegos
# Processing Record 5 of Set 11 | midvagur
# Processing Record 6 of Set 11 | taoudenni
# Processing Record 7 of Set 11 | porto murtinho
# Processing Record 8 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 11 | enriquillo
# Processing Record 10 of Set 11 | arkhangel'sk
# Processing Record 11 of Set 11 | boonville
# Processing Record 12 of Set 11 | orda
# Processing Record 13 of Set 11 | shenjiamen
# Processing Record 14 of Set 11 | chui
# Processing Record 15 of Set 11 | khash
# Processing Record 16 of Set 11 | vernon
# Processing Record 17 of Set 11 | howard springs
# Processing Record 18 of Set 11 | kondopoga
# Processing Record 19 of Set 11 | huanren
# Processing Record 20 of Set 11 | hobyo
# Processing Record 21 of Set 11 | cidreira
# Processing Record 22 of Set 11 | diebougou
# Processing Record 23 of Set 11 | cestos city
# Processing Record 24 of Set 11 | conception bay south
# Processing Record 25 of Set 11 | hell-ville
# Processing Record 26 of Set 11 | novyy urengoy
# Processing Record 27 of Set 11 | ciudad constitucion
# Processing Record 28 of Set 11 | yarmouth
# Processing Record 29 of Set 11 | fisterra
# Processing Record 30 of Set 11 | canutama
# Processing Record 31 of Set 11 | akureyri
# Processing Record 32 of Set 11 | rongelap
# Processing Record 33 of Set 11 | saksaul'skiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | tokar
# Processing Record 35 of Set 11 | argo
# Processing Record 36 of Set 11 | pucon
# Processing Record 37 of Set 11 | asau
# Processing Record 38 of Set 11 | costa teguise
# City not found. Skipping...
# Processing Record 39 of Set 11 | taiyuan
# Processing Record 40 of Set 11 | quellon
# Processing Record 41 of Set 11 | boden
# Processing Record 42 of Set 11 | mandalgovi
# Processing Record 43 of Set 11 | la ronge
# Processing Record 44 of Set 11 | piacabucu
# Processing Record 45 of Set 11 | lusambo
# Processing Record 46 of Set 11 | okondja
# Processing Record 47 of Set 11 | tillaberi
# Processing Record 48 of Set 11 | labuan bajo
# Processing Record 49 of Set 11 | doctor alberto oviedo mota
# Processing Record 0 of Set 12 | grants
# Processing Record 1 of Set 12 | kawerau
# Processing Record 2 of Set 12 | alto araguaia
# Processing Record 3 of Set 12 | bamboo flat
# Processing Record 4 of Set 12 | la'ie
# Processing Record 5 of Set 12 | lompoc
# Processing Record 6 of Set 12 | chabahar
# Processing Record 7 of Set 12 | bristol
# Processing Record 8 of Set 12 | nukunonu
# City not found. Skipping...
# Processing Record 9 of Set 12 | kalaleh
# Processing Record 10 of Set 12 | norwalk
# Processing Record 11 of Set 12 | mugia
# Processing Record 12 of Set 12 | puerto lempira
# Processing Record 13 of Set 12 | nagqu
# Processing Record 14 of Set 12 | newman
# Processing Record 15 of Set 12 | al kharj
# Processing Record 16 of Set 12 | la mira
# Processing Record 17 of Set 12 | talata mafara
# Processing Record 18 of Set 12 | lautoka
# Processing Record 19 of Set 12 | calingasta
# Processing Record 20 of Set 12 | shupiyan
# Processing Record 21 of Set 12 | chongjin
# Processing Record 22 of Set 12 | maragogi
# Processing Record 23 of Set 12 | puerto san jose
# Processing Record 24 of Set 12 | acapulco de juarez
# Processing Record 25 of Set 12 | semporna
# Processing Record 26 of Set 12 | elverum
# Processing Record 27 of Set 12 | rio branco do sul
# Processing Record 28 of Set 12 | kimbe
# Processing Record 29 of Set 12 | wakuya
# Processing Record 30 of Set 12 | nyrob
# Processing Record 31 of Set 12 | cuyo
# Processing Record 32 of Set 12 | bardai
# Processing Record 33 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 34 of Set 12 | bishkek
# Processing Record 35 of Set 12 | carutapera
# Processing Record 36 of Set 12 | okhotsk
# Processing Record 37 of Set 12 | talara
# Processing Record 38 of Set 12 | henderson
# Processing Record 39 of Set 12 | los mochis
# Processing Record 40 of Set 12 | kuytun
# Processing Record 41 of Set 12 | ulety
# Processing Record 42 of Set 12 | tra vinh
# Processing Record 43 of Set 12 | quartu sant'elena
# Processing Record 44 of Set 12 | lubumbashi
# Processing Record 45 of Set 12 | kez
# Processing Record 46 of Set 12 | blairgowrie
# Processing Record 47 of Set 12 | kalemie
# Processing Record 48 of Set 12 | ivdel'
# Processing Record 49 of Set 12 | poronaysk
# Processing Record 0 of Set 13 | khanna
# Processing Record 1 of Set 13 | sisimiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({
    "City": city_name,
    "Lat": city_lat, 
    "Lng": city_lng, 
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind,
    "Country": city_country,
    "Date": city_date
})

# Define a dictionary structure for header row styling
df_header_row = {
    'selector': 'th.col_heading',
    'props': 'background-color: bisque;'
}
   
# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data - minor data wrangling for hiding the index
city_data_df.head().style.hide(axis="index").set_table_styles([df_header_row])
# Out:
# <style type="text/css">
# #T_7a51e th.col_heading {
#   background-color: bisque;
# }
# </style>
# <table id="T_7a51e">
#   <thead>
#     <tr>
#       <th id="T_7a51e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_7a51e_level0_col1" class="col_heading level0 col1" >Lat</th>
#       <th id="T_7a51e_level0_col2" class="col_heading level0 col2" >Lng</th>
#       <th id="T_7a51e_level0_col3" class="col_heading level0 col3" >Max Temp</th>
#       <th id="T_7a51e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_7a51e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_7a51e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_7a51e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_7a51e_level0_col8" class="col_heading level0 col8" >Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_
td>
#     </tr>
#   </tbody>
# </table>

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data - minor data wrangling for hiding the index
city_data_df.head().style.hide(axis="index").set_table_styles([df_header_row])
# Out:
# <style type="text/css">
# #T_99346 th.col_heading {
#   background-color: bisque;
# }
# </style>
# <table id="T_99346">
#   <thead>
#     <tr>
#       <th id="T_99346_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_99346_level0_col1" class="col_heading level0 col1" >Lat</th>
#       <th id="T_99346_level0_col2" class="col_heading level0 col2" >Lng</th>
#       <th id="T_99346_level0_col3" class="col_heading level0 col3" >Max Temp</th>
#       <th id="T_99346_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_99346_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_99346_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_99346_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_99346_level0_col8" class="col_heading level0 col8" >Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99346_row0_col0" class="data row0 col0" >Neyshabur</td>
#       <td id="T_99346_row0_col1" class="data row0 col1" >36.213300</td>
#       <td id="T_99346_row0_col2" class="data row0 col2" >58.795800</td>
#       <td id="T_99346_row0_col3" class="data row0 col3" >41.880000</td>
#       <td id="T_99346_row0_col4" class="data row0 col4" >52</td>
#       <td id="T_99346_row0_col5" class="data row0 col5" >33</td>
#       <td id="T_99346_row0_col6" class="data row0 col6" >3.060000</td>
#       <td id="T_99346_row0_col7" class="data row0 col7" >IR</td>
#       <td id="T_99346_row0_col8" class="data row0 col8" >1707343926</td>
#     </tr>
#     <tr>
#       <td id="T_99346_row1_col0" class="data row1 col0" >I-n-Salah</td>
#       <td id="T_99346_row1_col1" class="data row1 col1" >27.193500</td>
#       <td id="T_99346_row1_col2" class="data row1 col2" >2.460700</td>
#       <td id="T_99346_row1_col3" class="data row1 col3" >62.190000</td>
#       <td id="T_99346_row1_col4" class="data row1 col4" >21</td>
#       <td id="T_99346_row1_col5" class="data row1 col5" >99</td>
#       <td id="T_99346_row1_col6" class="data row1 col6" >11.100000</td>
#       <td id="T_99346_row1_col7" class="data row1 col7" >DZ</td>
#       <td id="T_99346_row1_col8" class="data row1 col8" >1707344099</td>
#     </tr>
#     <tr>
#       <td id="T_99346_row2_col0" class="data row2 col0" >Flying Fish Cove</td>
#       <td id="T_99346_row2_col1" class="data row2 col1" >-10.421700</td>
#       <td id="T_99346_row2_col2" class="data row2 col2" >105.679100</td>
#       <td id="T_99346_row2_col3" class="data row2 col3" >76.680000</td>
#       <td id="T_99346_row2_col4" class="data row2 col4" >94</td>
#       <td id="T_99346_row2_col5" class="data row2 col5" >40</td>
#       <td id="T_99346_row2_col6" class="data row2 col6" >2.300000</td>
#       <td id="T_99346_row2_col7" class="data row2 col7" >CX</td>
#       <td id="T_99346_row2_col8" class="data row2 col8" >1707344099</td>
#     </tr>
#     <tr>
#       <td id="T_99346_row3_col0" class="data row3 col0" >Sola</td>
#       <td id="T_99346_row3_col1" class="data row3 col1" >-13.883300</td>
#       <td id="T_99346_row3_col2" class="data row3 col2" >167.550000</td>
#       <td id="T_99346_row3_col3" class="data row3 col3" >84.870000</td>
#       <td id="T_99346_row3_col4" class="data row3 col4" >79</td>
#       <td id="T_99346_row3_col5" class="data row3 col5" >75</td>
#       <td id="T_99346_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_99346_row3_col7" class="data row3 col7" >VU</td>
#       <td id="T_99346_row3_col8" class="data row3 col8" >1707344100</td>
#     </tr>
#     <tr>
#       <td id="T_99346_row4_col0" class="data row4 col0" >Invercargill</td>
#       <td id="T_99346_row4_col1" class="data row4 col1" >-46.400000</td>
#       <td id="T_99346_row4_col2" class="data row4 col2" >168.350000</td>
#       <td id="T_99346_row4_col3" class="data row4 col3" >61.020000</td>
#       <td id="T_99346_row4_col4" class="data row4 col4" >63</td>
#       <td id="T_99346_row4_col5" class="data row4 col5" >46</td>
#       <td id="T_99346_row4_col6" class="data row4 col6" >15.010000</td>
#       <td id="T_99346_row4_col7" class="data row4 col7" >NZ</td>
#       <td id="T_99346_row4_col8" class="data row4 col8" >1707344100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# Step 1: Use the dataframe created above to assign the axes values for the scatter plot
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

# Step 2: Generate a scatter plot based with added customization
pyplt.title(f"City Latitude vs. Max Temperature ({todays_date})", fontsize = 14, fontstyle = 'italic', pad = 15)
pyplt.xlabel("City Latitude", fontsize = 10, fontweight = 'bold')
pyplt.ylabel("Max Temperature (F)", fontsize = 10, fontweight = 'bold')
pyplt.scatter(x_values, y_values, edgecolor = "midnightblue", s = 30, color = "tomato")
pyplt.grid()

# Step 3: Save the figure
pyplt.savefig("output_data/Figure 1 - City Latitude vs. Max Temperature.png", bbox_inches = 'tight', dpi = 200)

# Step 4: Display the plot
pyplt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

# Step 2: Generate a scatter plot based with added customization
pyplt.title(f"City Latitude vs. Humidity ({todays_date})", fontsize = 14, fontstyle = 'italic', pad = 15)
pyplt.xlabel("City Latitude", fontsize = 10, fontweight = 'bold')
pyplt.ylabel("Humidity (%)", fontsize = 10, fontweight = 'bold')
pyplt.scatter(x_values, y_values, edgecolor = "midnightblue", s = 30, color = "tomato")
pyplt.grid()

# Step 3: Save the figure
pyplt.savefig("output_data/Figure 2 - City Latitude vs. Humidity.png", bbox_inches = 'tight', dpi = 200)

# Step 4: Display the plot
pyplt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

# Step 2: Generate a scatter plot based with added customization
pyplt.title(f"City Latitude vs. Cloudiness ({todays_date})", fontsize = 14, fontstyle = 'italic', pad = 15)
pyplt.xlabel("City Latitude", fontsize = 10, fontweight = 'bold')
pyplt.ylabel("Cloudiness (%)", fontsize = 10, fontweight = 'bold')
pyplt.scatter(x_values, y_values, edgecolor = "midnightblue", s = 30, color = "tomato")
pyplt.grid()

# Step 3: Save the figure
pyplt.savefig("output_data/Figure 3 - City Latitude vs. Cloudiness.png", bbox_inches = 'tight', dpi = 200)

# Step 4: Display the plot
pyplt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

# Step 2: Generate a scatter plot based with added customization
pyplt.title(f"City Latitude vs. Wind Speed ({todays_date})", fontsize = 14, fontstyle = 'italic', pad = 15)
pyplt.xlabel("City Latitude", fontsize = 10, fontweight = 'bold')
pyplt.ylabel("Wind Speed (m/s)", fontsize = 10, fontweight = 'bold')
pyplt.scatter(x_values, y_values, edgecolor = "midnightblue", s = 30, color = "tomato")
pyplt.grid()

# Step 3: Save the figure
pyplt.savefig("output_data/Figure 4 - City Latitude vs. Wind Speed.png", bbox_inches = 'tight', dpi = 200)

# Step 4: Display the plot
pyplt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere, line_eq_text_coordinates):
    
    # Step 1: Use the linear regression scipy class
    result_regression = linregress(x_values, y_values)
    # Calculate the slope and intercept of the desired linear regression equation
    slope = result_regression[0]; intercept = result_regression[1];
    
    # Step 2: Generate the line equation for the regression
    # Use ANSI Escape code for bold text for formating the result
    regress_values = x_values * slope + intercept
    linear_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(f"Linear Regression Line Equation: \033[1m{linear_equation}\033[0m")

    # Step 3: Generate the linear regression plot based on the above values with customization
    pyplt.rcParams['figure.figsize'] = [10, 6]
    pyplt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label}", fontsize = 14, fontstyle = 'italic', pad = 15)
    pyplt.xlabel(x_label, fontsize = 10, fontweight = 'bold')
    pyplt.ylabel(y_label, fontsize = 10, fontweight = 'bold')
    pyplt.scatter(x_values, y_values, edgecolor = "midnightblue", s = 30, color = "lightcoral")
    pyplt.annotate(linear_equation, xy = line_eq_text_coordinates, fontsize=12, color="darkviolet")
    pyplt.plot(x_values, regress_values, '-g')
    
    # Step 4: Use Pearson's correlation method to compute the correlation coffecient for the given data
    # Note: Round to two decimal places and get the first value of the result
    # Use ANSI Escape code for bold text for formating the result
    correlation_coeff = round(st.pearsonr(x_values, y_values)[0],2)
    print(f"The r-value (correlation coefficient) of this relationship is: \033[1m{correlation_coeff}\033[0m")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head().style.set_table_styles([df_header_row])
# Out:
# <style type="text/css">
# #T_eec72 th.col_heading {
#   background-color: bisque;
# }
# </style>
# <table id="T_eec72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eec72_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_eec72_level0_col1" class="col_heading level0 col1" >Lat</th>
#       <th id="T_eec72_level0_col2" class="col_heading level0 col2" >Lng</th>
#       <th id="T_eec72_level0_col3" class="col_heading level0 col3" >Max Temp</th>
#       <th id="T_eec72_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_eec72_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_eec72_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_eec72_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_eec72_level0_col8" class="col_heading level0 col8" >Date</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City_ID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eec72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eec72_row0_col0" class="data row0 col0" >Neyshabur</td>
#       <td id="T_eec72_row0_col1" class="data row0 col1" >36.213300</td>
#       <td id="T_eec72_row0_col2" class="data row0 col2" >58.795800</td>
#       <td id="T_eec72_row0_col3" class="data row0 col3" >41.880000</td>
#       <td id="T_eec72_row0_col4" class="data row0 col4" >52</td>
#       <td id="T_eec72_row0_col5" class="data row0 col5" >33</td>
#       <td id="T_eec72_row0_col6" class="data row0 col6" >3.060000</td>
#       <td id="T_eec72_row0_col7" class="data row0 col7" >IR</td>
#       <td id="T_eec72_row0_col8" class="data row0 col8" >1707343926</td>
#     </tr>
#     <tr>
#       <th id="T_eec72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City_ID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db2d3_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_db2d3_row0_col0" class="data row0 col0" >Flying Fish Cove</td>
#       <td id="T_db2d3_row0_col1" class="data row0 col1" >-10.421700</td>
#       <td id="T_db2d3_row0_col2" class="data row0 col2" >105.679100</td>
#       <td id="T_db2d3_row0_col3" class="data row0 col3" >76.680000</td>
#       <td id="T_db2d3_row0_col4" class="data row0 col4" >94</td>
#       <td id="T_db2d3_row0_col5" class="data row0 col5" >40</td>
#       <td id="T_db2d3_row0_col6" class="data row0 col6" >2.300000</td>
#       <td id="T_db2d3_row0_col7" class="data row0 col7" >CX</td>
#       <td id="T_db2d3_row0_col8" class="data row0 col8" >1707344099</td>
#     </tr>
#     <tr>
#       <th id="T_db2d3_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_db2d3_row1_col0" class="data row1 col0" >Sola</td>
#       <td id="T_db2d3_row1_col1" class="data row1 col1" >-13.883300</td>
#       <td id="T_db2d3_row1_col2" class="data row1 col2" >167.550000</td>
#       <td id="T_db2d3_row1_col3" class="data row1 col3" >84.870000</td>
#       <td id="T_db2d3_row1_col4" class="data row1 col4" >79</td>
#       <td id="T_db2d3_row1_col5" class="data row1 col5" >75</td>
#       <td id="T_db2d3_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_db2d3_row1_col7" class="data row1 col7" >VU</td>
#       <td id="T_db2d3_row1_col8" class="data row1 col8" >1707344100</td>
#     </tr>
#     <tr>
#       <th id="T_db2d3_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_db2d3_row2_col0" class="data row2 col0" >Invercargill</td>
#       <td id="T_db2d3_row2_col1" class="data row2 col1" >-46.400000</td>
#       <td id="T_db2d3_row2_col2" class="data row2 col2" >168.350000</td>
#       <td id="T_db2d3_row2_col3" class="data row2 col3" >61.020000</td>
#       <td id="T_db2d3_row2_col4" class="data row2 col4" >63</td>
#       <td id="T_db2d3_row2_col5" class="data row2 col5" >46</td>
#       <td id="T_db2d3_row2_col6" class="data row2 col6" >15.010000</td>
#       <td id="T_db2d3_row2_col7" class="data row2 col7" >NZ</td>
#       <td id="T_db2d3_row2_col8" class="data row2 col8" >1707344100</td>
#     </tr>
#     <tr>
#       <th id="T_db2d3_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_db2d3_row3_col0" class="data row3 col0" >Waitangi</td>
#       <td id="T_db2d3_row3_col1" class="data row3 col1" >-43.953500</td>
#       <td id="T_db2d3_row3_col2" class="data row3 col2" >-176.559700</td>
#       <td id="T_db2d3_row3_col3" class="data row3 col3" >65.820000</td>
#       <td id="T_db2d3_row3_col4" class="data row3 col4" >91</td>
#       <td id="T_db2d3_row3_col5" class="data row3 col5" >83</td>
#       <td id="T_db2d3_row3_col6" class="data row3 col6" >5.280000</td>
#       <td id="T_db2d3_row3_col7" class="data row3 col7" >NZ</td>
#       <td id="T_db2d3_row3_col8" class="data row3 col8" >1707344100</td>
#     </tr>
#     <tr>
#       <th id="T_db2d3_level0_row4" class="row_heading level0 row4" >15</th>
#       <td id="T_db2d3_row4_col0" class="data row4 col0" >Puerto Natales</td>
#       <td id="T_db2d3_row4_col1" class="data row4 col1" >-51.723600</td>
#       <td id="T_db2d3_row4_col2" class="data row4 col2" >-72.487500</td>
#       <td id="T_db2d3_row4_col3" class="data row4 col3" >48.920000</td>
#       <td id="T_db2d3_row4_col4" class="data row4 col4" >80</td>
#       <td id="T_db2d3_row4_col5" class="data row4 col5" >87</td>
#       <td id="T_db2d3_row4_col6" class="data row4 col6" >14.970000</td>
#       <td id="T_db2d3_row4_col7" class="data row4 col7" >CL</td>
#       <td id="T_db2d3_row4_col8" class="data row4 col8" >1707344103</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Step 1: Define the axes values for the plot 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (10, 10))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 5 - North_Hemi Latitude vs. Max Temperature.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = -1.35x + 93.14
# The r-value (correlation coefficient) of this relationship is: -0.84

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 50))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 6 - South_Hemi Latitude vs. Max Temperature.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = 0.36x + 82.74
# The r-value (correlation coefficient) of this relationship is: 0.49

# %% [markdown]
# #### Observation and Insights:
# ---
# - *Latitude vs. Maximum Temperature Linear Relationship*: For both the northern and southern hemispheres, based on the regression analysis, it is evident that the correlation between latitude and maximum temperature across cities is strong.<br>
# - *Correlation of the linear relationship*: Northern hemisphere has a higher correlation (*0.84*) than the Southern Hemisphere (*0.49*). This indicates that as we move further away from the equator the drop in temperatures is more linear in relationship than the corresponding increase in temperature in southern hemisphere by approaching closer to the equator (latitude = 0).<br>
# ---

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Northern", (40, 10))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 7 - North_Hemi Latitude vs. Humidity.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = 0.57x + 50.76
# The r-value (correlation coefficient) of this relationship is: 0.47

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Southern", (-55, 25))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 7 - South_Hemi Latitude vs. Humidity.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = 0.5x + 85.25
# The r-value (correlation coefficient) of this relationship is: 0.4

# %% [markdown]
# #### Observation and Insights:
# ---
# - *Latitude vs. Humidity Linear Relationship*: For both the northern and southern hemispheres, based on the regression analysis, there is weak correlation between latitude and humidity across cities.<br>
# - *Correlation of the linear relationship*: Northern hemisphere has a slightly higher correlation (*0.47*) than the Southern Hemisphere (*0.40*) with cities in a higher latitude having a more linear relationship to humidity. However, the Southern hemisphere seems to have very little to no correlation with values spread across the scatter plot showing this relationship.<br>
# ---

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Cloudiness (%)", "Northern", (10, 62))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 8 - North_Hemi Latitude vs. Cloudiness.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = 0.7x + 35.34
# The r-value (correlation coefficient) of this relationship is: 0.34

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Cloudiness (%)", "Southern", (-47, 62))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 9  - South_Hemi Latitude vs. Cloudiness.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = 0.29x + 69.26
# The r-value (correlation coefficient) of this relationship is: 0.11

# %% [markdown]
# #### Observation and Insights:
# ---
# - *Latitude vs. Cloudiness Linear Relationship*: For both the northern and southern hemispheres, based on the regression analysis, there is hardly **any** correlation between latitude and cloudiness across cities.The scatter plot for each of these shows values that are distributed all over the place. <br>
# - *Correlation of the linear relationship*: Northern hemisphere has a slightly higher correlation (*0.34*) than the Southern Hemisphere (*0.11*) in this relationship. However, there is no clear linear relationship for either hemispheres in this regard, as the values seem to be distributed across latitudes for each plot.<br>
# ---

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern", (5, 30))

# Step 3: Save the figure 
pyplt.savefig("./output_data/Figure 10 - North_Hemi Latitude vs. Wind Speed.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = -0.04x + 10.35
# The r-value (correlation coefficient) of this relationship is: -0.12

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Step 2: Call the Linear Regression function defined earlier with relevant arguments as parameters
linear_regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern", (-55, 10))

# Step 3: Save the figure
pyplt.savefig("./output_data/Figure 11 - South_Hemi Latitude vs. Wind Speed.png", bbox_inches="tight", dpi = 200)

# Step 4: Display the plot
pyplt.show()
# Out:
# Linear Regression Line Equation: y = -0.13x + 5.89
# The r-value (correlation coefficient) of this relationship is: -0.25

# %% [markdown]
# #### Observation and Insights:
# ---
# - *Latitude vs. Wind Speed Linear Relationship*: For both the northern and southern hemispheres, based on the regression analysis, there is hardly **any** correlation between latitude and cloudiness across cities. The scatter plot for each of these shows values that are distributed all over across latitudes. <br>
# - *Correlation of the linear relationship*: The Northern hemisphere has a slightly higher correlation (*-0.12*) than the Southern Hemisphere (*-0.25*) in this relationship. However, for cities that are closer to the equator in either hemisphere (*from 0 degree to around 40 degrees*), both hemispheres seem to have similar wind speeds (in the range of 0 mph to 10 mph).<br>
# ---
